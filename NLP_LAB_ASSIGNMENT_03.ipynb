# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a54130-beep/NLP-1/blob/main/NLP_LAB_ASSIGNMENT_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TASK #**02**

# %%
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""
tokens = nltk.word_tokenize(SRUniversity)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
for token in doc:
  print(token.text, token.pos_)
# Out:
# The DET
# SR PROPN
# University PROPN
# campus NOUN
# is AUX
# located VERB
# in ADP
# Ananthasagar PROPN
# village NOUN
# of ADP
# Hasanparthy PROPN
# Mandal PROPN
# in ADP
# Warangal PROPN
# , PUNCT
# Telangana PROPN
# , PUNCT
# India PROPN
# . PUNCT
#
#  SPACE
# It PRON
# is AUX
# in ADP
# 150 NUM
# acres NOUN
# , PUNCT
# with ADP
# both DET
# separate ADJ
# hostel NOUN
# facilities NOUN
# for ADP
# boys NOUN
# and CCONJ
# girls NOUN
# . PUNCT
#
#  SPACE
# There PRON
# is VERB
# a DET
# huge ADJ
# central ADJ
# library NOUN
# along ADP
# with ADP
# Indias PROPN
# largest ADJ
# Technology PROPN
# Business PROPN
# Incubator PROPN
# ( PUNCT
# TBI PROPN
# ) PUNCT
# in ADP
# tier NOUN
# 2 NUM
# cities NOUN
# . PUNCT

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
for token in doc:
  print(token.text, token.pos_, token.tag_)
# Out:
# The DET DT
# SR PROPN NNP
# University PROPN NNP
# campus NOUN NN
# is AUX VBZ
# located VERB VBN
# in ADP IN
# Ananthasagar PROPN NNP
# village NOUN NN
# of ADP IN
# Hasanparthy PROPN NNP
# Mandal PROPN NNP
# in ADP IN
# Warangal PROPN NNP
# , PUNCT ,
# Telangana PROPN NNP
# , PUNCT ,
# India PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# It PRON PRP
# is AUX VBZ
# in ADP IN
# 150 NUM CD
# acres NOUN NNS
# , PUNCT ,
# with ADP IN
# both DET DT
# separate ADJ JJ
# hostel NOUN NN
# facilities NOUN NNS
# for ADP IN
# boys NOUN NNS
# and CCONJ CC
# girls NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# There PRON EX
# is VERB VBZ
# a DET DT
# huge ADJ JJ
# central ADJ JJ
# library NOUN NN
# along ADP IN
# with ADP IN
# Indias PROPN NNP
# largest ADJ JJS
# Technology PROPN NNP
# Business PROPN NNP
# Incubator PROPN NNP
# ( PUNCT -LRB-
# TBI PROPN NNP
# ) PUNCT -RRB-
# in ADP IN
# tier NOUN NN
# 2 NUM CD
# cities NOUN NNS
# . PUNCT .

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
nouns = []
verbs = []
for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'SR': 1, 'University': 1, 'campus': 1, 'Ananthasagar': 1, 'village': 1, 'Hasanparthy': 1, 'Mandal': 1, 'Warangal': 1, 'Telangana': 1, 'India': 1, 'acres': 1, 'hostel': 1, 'facilities': 1, 'boys': 1, 'girls': 1, 'library': 1, 'Indias': 1, 'Technology': 1, 'Business': 1, 'Incubator': 1, 'TBI': 1, 'tier': 1, 'cities': 1})
# Verb Frequency: Counter({'located': 1, 'is': 1})

# %% [markdown]
# # TASK #**01**

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
Sentence="Students are learning Natural Language Processing"
tokens = nltk.word_tokenize(Sentence)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Students', 'NNS'), ('are', 'VBP'), ('learning', 'VBG'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP')]
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Students are learning Natural Language Processing")
for token in doc:
  print(token.text, token.pos_)
# Out:
# Students NOUN
# are AUX
# learning VERB
# Natural PROPN
# Language PROPN
# Processing NOUN

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying a startup in India.")
for token in doc:
  print(token.text, token.pos_, token.tag_)
# Out:
# Apple PROPN NNP
# is AUX VBZ
# looking VERB VBG
# at ADP IN
# buying VERB VBG
# a DET DT
# startup NOUN NN
# in ADP IN
# India PROPN NNP
# . PUNCT .

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = "Loving the new AI features  #AI #MachineLearning"
doc = nlp(text)
nouns = []
verbs = []
for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'AI': 2, 'MachineLearning': 1})
# Verb Frequency: Counter({'Loving': 1, 'features': 1})

# %% [markdown]
# # TASK #**03**

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
text="Morning light spills across quiet streets, inviting reflection and movement. People wake, carrying hopes, worries, and small plans for progress. Coffee warms hands, screens glow with messages, and conversations begin again. Each choice, however ordinary, shapes the day’s direction. Kindness multiplies when practiced, focus sharpens with patience, and effort compounds quietly. By evening, lessons settle, gratitude grows, and tomorrow waits, ready for improvement, resilience, curiosity, and better questions than yesterday offered. Sleep restores courage, dreams rehearse possibilities, and dawn returns with chances to learn, build, listen, forgive, adapt, explore, connect, create, refine, share, lead, rest, and begin again, wiser together"
tokens = nltk.word_tokenize(text)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Morning', 'VBG'), ('light', 'NN'), ('spills', 'NNS'), ('across', 'IN'), ('quiet', 'JJ'), ('streets', 'NNS'), (',', ','), ('inviting', 'VBG'), ('reflection', 'NN'), ('and', 'CC'), ('movement', 'NN'), ('.', '.'), ('People', 'NNS'), ('wake', 'VBP'), (',', ','), ('carrying', 'VBG'), ('hopes', 'NNS'), (',', ','), ('worries', 'NNS'), (',', ','), ('and', 'CC'), ('small', 'JJ'), ('plans', 'NNS'), ('for', 'IN'), ('progress', 'NN'), ('.', '.'), ('Coffee', 'NN'), ('warms', 'NNS'), ('hands', 'NNS'), (',', ','), ('screens', 'NNS'), ('glow', 'VBP'), ('with', 'IN'), ('messages', 'NNS'), (',', ','), ('and', 'CC'), ('conversations', 'NNS'), ('begin', 'VBP'), ('again', 'RB'), ('.', '.'), ('Each', 'DT'), ('choice', 'NN'), (',', ','), ('however', 'RB'), ('ordinary', 'JJ'), (',', ','), ('shapes', 'VBZ'), ('the', 'DT'), ('day', 'NN'), ('’', 'NNP'), ('s', 'JJ'), ('direction', 'NN'), ('.', '.'), ('Kindness', 'NNP'), ('multiplies', 'NNS'), ('when', 'WRB'), ('practiced', 'VBN'), (',', ','), ('focus', 'VB')
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("""Morning light spills across quiet streets, inviting reflection and movement. People wake, carrying hopes, worries, and small plans for progress. Coffee warms hands, screens glow with messages, and conversations begin again. Each choice, however ordinary, shapes the day’s direction. Kindness multiplies when practiced, focus sharpens with patience, and effort compounds quietly. By evening, lessons settle, gratitude grows, and tomorrow waits, ready for improvement, resilience, curiosity, and better questions than yesterday offered. Sleep restores courage, dreams rehearse possibilities, and dawn returns with chances to learn, build, listen, forgive, adapt, explore, connect, create, refine, share, lead, rest, and begin again, wiser together.
Morning light spills across quiet streets, inviting reflection and movement. People wake, carrying hopes, worries, and small plans for progress. Coffee warms hands, screens glow with messages, and conversations begin again. Each choice, however ordinary, shapes the day’s direction. Kindness multiplies when practiced, focus sharpens with patience, and effort compounds quietly. By evening, lessons settle, gratitude grows, and tomorrow waits, ready for improvement, resilience, curiosity, and better questions than yesterday offered. Sleep restores courage, dreams rehearse possibilities, and dawn returns with chances to learn, build, listen, forgive, adapt, explore, connect, create, refine, share, lead, rest, and begin again, wiser together.
""")
for token in doc:
  print(token.text, token.pos_)
# Out:
# Morning PROPN
# light NOUN
# spills VERB
# across ADP
# quiet ADJ
# streets NOUN
# , PUNCT
# inviting VERB
# reflection NOUN
# and CCONJ
# movement NOUN
# . PUNCT
# People NOUN
# wake VERB
# , PUNCT
# carrying VERB
# hopes NOUN
# , PUNCT
# worries NOUN
# , PUNCT
# and CCONJ
# small ADJ
# plans NOUN
# for ADP
# progress NOUN
# . PUNCT
# Coffee NOUN
# warms VERB
# hands NOUN
# , PUNCT
# screens NOUN
# glow VERB
# with ADP
# messages NOUN
# , PUNCT
# and CCONJ
# conversations NOUN
# begin VERB
# again ADV
# . PUNCT
# Each DET
# choice NOUN
# , PUNCT
# however ADV
# ordinary ADJ
# , PUNCT
# shapes VERB
# the DET
# day NOUN
# ’s PART
# direction NOUN
# . PUNCT
# Kindness NOUN
# multiplies NOUN
# when SCONJ
# practiced VERB
# , PUNCT
# focus VERB
# sharpens NOUN
# with ADP
# patience NOUN
# , PUNCT
# and CCONJ
# effort NOUN
# compounds NOUN
# quietly ADV
# . PUNCT
# By ADP
# evening NOUN
# , PUNCT
# lessons NOUN
# settle VERB
# , PUNCT
# gratitude NOUN
# grows VERB
# , PUNCT
# and CCONJ
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Morning light spills across quiet streets, inviting reflection and movement. People wake, carrying hopes, worries, and small plans for progress. Coffee warms hands, screens glow with messages, and conversations begin again. Each choice, however ordinary, shapes the day’s direction. Kindness multiplies when practiced, focus sharpens with patience, and effort compounds quietly. By evening, lessons settle, gratitude grows, and tomorrow waits, ready for improvement, resilience, curiosity, and better questions than yesterday offered. Sleep restores courage, dreams rehearse possibilities, and dawn returns with chances to learn, build, listen, forgive, adapt, explore, connect, create, refine, share, lead, rest, and begin again, wiser together.")
for token in doc:
  print(token.text, token.pos_, token.tag_)
# Out:
# Morning PROPN NNP
# light NOUN NN
# spills VERB VBZ
# across ADP IN
# quiet ADJ JJ
# streets NOUN NNS
# , PUNCT ,
# inviting VERB VBG
# reflection NOUN NN
# and CCONJ CC
# movement NOUN NN
# . PUNCT .
# People NOUN NNS
# wake VERB VBP
# , PUNCT ,
# carrying VERB VBG
# hopes NOUN NNS
# , PUNCT ,
# worries NOUN NNS
# , PUNCT ,
# and CCONJ CC
# small ADJ JJ
# plans NOUN NNS
# for ADP IN
# progress NOUN NN
# . PUNCT .
# Coffee NOUN NN
# warms VERB VBZ
# hands NOUN NNS
# , PUNCT ,
# screens NOUN NNS
# glow VERB VBP
# with ADP IN
# messages NOUN NNS
# , PUNCT ,
# and CCONJ CC
# conversations NOUN NNS
# begin VERB VBP
# again ADV RB
# . PUNCT .
# Each DET DT
# choice NOUN NN
# , PUNCT ,
# however ADV RB
# ordinary ADJ JJ
# , PUNCT ,
# shapes VERB VBZ
# the DET DT
# day NOUN NN
# ’s PART POS
# direction NOUN NN
# . PUNCT .
# Kindness NOUN NN
# multiplies NOUN NNS
# when SCONJ WRB
# practiced VERB VBN
# , PUNCT ,
# focus VERB VBP
# sharpens NOUN NNS
# with ADP IN
# patience NOUN NN
# ...

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = "Loving the new AI features  #AI #MachineLearning"
doc = nlp("""Morning light spills across quiet streets, inviting reflection and movement. People wake, carrying hopes, worries, and small plans for progress. Coffee warms hands, screens glow with messages, and conversations begin again. Each choice, however ordinary, shapes the day’s direction. Kindness multiplies when practiced, focus sharpens with patience, and effort compounds quietly. By evening, lessons settle, gratitude grows, and tomorrow waits, ready for improvement, resilience, curiosity, and better questions than yesterday offered.
Sleep restores courage, dreams rehearse possibilities, and dawn returns with chances to learn, build, listen, forgive, adapt, explore, connect, create, refine, share, lead, rest, and begin again, wiser together.
Morning light spills across quiet streets, inviting reflection and movement. People wake, carrying hopes, worries, and small plans for progress. Coffee warms hands, screens glow with messages, and conversations begin again. Each choice, however ordinary, shapes the day’s direction. Kindness multiplies when practiced, focus sharpens with patience, and effort compounds quietly. By evening, lessons settle, gratitude grows, and tomorrow waits, ready for improvement, resilience, curiosity, and better questions than yesterday offered.
Sleep restores courage, dreams rehearse possibilities, and dawn returns with chances to learn, build, listen, forgive, adapt, explore, connect, create, refine, share, lead, rest, and begin again, wiser together.
""")
nouns = []
verbs = []
for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'Morning': 2, 'light': 2, 'streets': 2, 'reflection': 2, 'movement': 2, 'People': 2, 'hopes': 2, 'worries': 2, 'plans': 2, 'progress': 2, 'Coffee': 2, 'hands': 2, 'screens': 2, 'messages': 2, 'conversations': 2, 'choice': 2, 'day': 2, 'direction': 2, 'Kindness': 2, 'multiplies': 2, 'sharpens': 2, 'patience': 2, 'effort': 2, 'compounds': 2, 'evening': 2, 'lessons': 2, 'gratitude': 2, 'tomorrow': 2, 'waits': 2, 'improvement': 2, 'resilience': 2, 'curiosity': 2, 'questions': 2, 'yesterday': 2, 'Sleep': 2, 'courage': 2, 'dreams': 2, 'possibilities': 2, 'dawn': 2, 'returns': 2, 'chances': 2, 'adapt': 2, 'explore': 2, 'refine': 2, 'share': 2, 'lead': 2, 'rest': 2})
# Verb Frequency: Counter({'begin': 4, 'spills': 2, 'inviting': 2, 'wake': 2, 'carrying': 2, 'warms': 2, 'glow': 2, 'shapes': 2, 'practiced': 2, 'focus': 2, 'settle': 2, 'grows': 2, 'offered': 2, 'restores': 2, 'rehearse': 2, 'learn': 2, 'build': 2, 'listen': 2, 'forgive': 2, 'connect': 2, 'create': 2})
